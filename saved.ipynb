# %%
from pysanger import *
import matplotlib.pyplot as plt

import os
from Bio import SeqIO

from tqdm.notebook import tqdm

with open("data/bfp-expression-control-mcherry-flag-hlpla-pcdna3-w37v.fasta") as file:
    for record in SeqIO.parse(file, "fasta"):
        template = record.seq

def tokenize_fp_make_id(inp):
    tokens = inp.replace('-', '_').split('_')
    user = tokens[0]
    construct = tokens[2]
    num = tokens[3]

    forward = 'Mcherry' in tokens
    reverse = 'WPRE' in tokens

    if not forward and not reverse:
        raise Exception('Neither forward nor reverse! Invalid filename.')
    else:
        if forward:
            primer = 'MCHERRY'
            direction = 'FORWARD'
            strand = 1
        else:
            primer = 'WPRE'
            direction = 'REVERSE'
            strand = -1

    id = f"{user}_{construct}_{num}_{primer}_{direction}"

    return id, strand

region = "read"
fp = 'PC_812288-1030_30_PC-442--Mcherry-Seq-Forward_C06.ab1'
id, strand = tokenize_fp_make_id(fp)
abidata = abi_to_dict(f"peter_data/{fp}")

if strand == 1:
    template_limits = (4660, 5250)
else:
    template_limits = (5000, 5740)

translation_limits = (4702, None)

consensus_seq_set = generate_consensusseq(abidata)

if strand == 1: 
    subject = consensus_seq_set[0]

if strand == -1:
    subject = consensus_seq_set[1] 

if template_limits is not None:
    template_start = max(0, template_limits[0]-1) #adjust for 0-based indexing
    if template_limits[1] is None:
        template_end = len(template)
    else:
        template_end = min(len(template), template_limits[1])

    if template_start >= template_end:
        raise ValueError("Invalid template limits specified! Template start point should be less than template end point.")
else:
    template_start = 0
    template_end = len(template)

if translation_limits is not None:
    translation_start = max(0, translation_limits[0]-1)
    if translation_limits[1] is None:
        translation_end = len(template)
    else:
        translation_end = min(len(template), translation_limits[1])

template = template[template_start:template_end]

alignments = pairwise2.align.globalms(template, subject, 2, 0, -10, -1, penalize_end_gaps=False)
atemplate = alignments[0][0]
asubject = alignments[0][1]

ts = len(atemplate) - len(atemplate.lstrip('-'))
te = len(atemplate) - len(atemplate.rstrip('-'))

ss = len(asubject) - len(asubject.lstrip('-'))
se = len(asubject) - len(asubject.rstrip('-'))

#modify to proper indices
te = len(atemplate) - te 
se = len(asubject)  - se

if region == "template":
    start, end = ts, te
elif region == 'read':
    start, end = ss, se
else:
    raise ValueError("Invalid region specified!")

asubject  = asubject[start:end]
atemplate = atemplate[start:end]

if len(asubject) != len(atemplate):
    raise ValueError("Subject and template lengths do not match after truncation!")

length = len(asubject)

if region == 'read':
    t_start_base = max(template_start, template_start+ss-ts)
    s_start_base = 0
elif region == 'template':
    t_start_base = template_start
    s_start_base = max(0, ts-ss)

# %%
remove_start_num = len(atemplate) - len(atemplate.lstrip('-'))
at = atemplate.lstrip('-')
asub = asubject[remove_start_num:]

starting_codon = 1
starting_base = t_start_base + 1 #return to 1 index

def remove_index(inp_str, remove):
    char_removed = 0
    for idx in range(len(inp_str)):
        if inp_str[idx] != '-':
            char_removed += 1
        
        if char_removed == remove:
            return idx + 1


if translation_start > t_start_base:
    remove = translation_start - t_start_base #need to cut to remove this many bases from the start of the template
else:
    remove = (translation_start - t_start_base) % 3#need to cut to remove this many bases from the start of the template
    codon = starting_codon - (remove/3) #rounds up

starting_base += remove

at = at[remove_index(at, remove):]
asub = asub[remove_index(at, remove):]

temp_chars = len(at.rstrip('-')) - at.rstrip('-').count('-') #number of characters in template minus number of gaps
temp_chars = temp_chars // 3 * 3 #round down to nearest multiple of 3

at = at[:remove_index(at, temp_chars)]
asub = asub[:remove_index(at, temp_chars)]

#cut end of at, asub

#cluster atemplate into 3 letter chunks from template
at_codons = []
asub_codons = []
template_nt_pos = []
codon_num = []

current_codon = starting_codon
current_nt_pos = starting_base
curr_template_codon = ''
curr_subject_codon = ''
n_template_nt = 0
curr_codon_pos = []

for tc, sc in zip(at, asub):
    curr_template_codon += tc
    curr_subject_codon += sc
    curr_codon_pos.append(current_nt_pos)
    
    if tc != '-':
        n_template_nt += 1
        current_nt_pos += 1
    
    if n_template_nt == 3:
        at_codons.append(curr_template_codon)
        asub_codons.append(curr_subject_codon)
        template_nt_pos.append(curr_codon_pos)
        codon_num.append(current_codon)
        
        curr_template_codon = ''
        curr_subject_codon = ''
        curr_codon_pos = []
        n_template_nt = 0
        current_codon += 1    

if n_template_nt != 0:
    raise ValueError('Something has gone wrong :(')

insertions = []
deletions = []
nt_mismatches = []
silent_mutations = []
missense_mutations = []
frameshift_mutations = []

for at_codon, as_codon, codon_pos, curr_codon_num in zip(at_codons, asub_codons, template_nt_pos, codon_num):
    for at_codon_nt, as_codon_nt, nt_pos in zip(at_codon, as_codon, codon_pos):
        if at_codon_nt == '-':
            insertions.append(f"{nt_pos}(ins{as_codon_nt.upper()})")
        elif as_codon_nt == '-':
            deletions.append(f"{nt_pos}(del{at_codon_nt.upper()})")
        elif at_codon_nt != as_codon_nt:
            nt_mismatches.append(f"{nt_pos}({at_codon_nt.upper()}->{as_codon_nt.upper()})")

    at_codon_s = at_codon.strip('-').upper()
    as_codon_s = as_codon.strip('-').upper()

    if len(as_codon_s) != 3 or len(at_codon_s) != 3:
        frameshift_mutations.append(f"{curr_codon_num}")
    else:
        #both codons are 3 nt long
        at_aa = translate([at_codon_s])[0]
        as_aa = translate([as_codon_s])[0]

        if at_codon_s != as_codon_s:
            if at_aa == as_aa:
                silent_mutations.append(f"{curr_codon_num}")
            else:
                missense_mutations.append(f"{at_aa}{curr_codon_num}{as_aa}")

insertions = "; ".join(insertions)
deletions = "; ".join(deletions)
nt_mismatches = "; ".join(nt_mismatches)
silent_mutations = "; ".join(silent_mutations)
missense_mutations = "; ".join(missense_mutations)
frameshift_mutations = "; ".join(frameshift_mutations)

stats = pd.DataFrame({'id': id, 'alignment_score': alignments[0].score, 'nt_insertions' : [insertions], 'nt_deletions': [deletions], 'nt_mismatches': [nt_mismatches], 'silent_mutations': [silent_mutations], 'missense_mutations': [missense_mutations], 'gap_mutations': [frameshift_mutations]})

# %%
translate([asub_codons[7]])
# Out:
# ['L']

# %%
translate(asub_codons[7])
# Out:
# ['-', '-', '-']

# %%
translate(at_codons[7])
# Out:
# ['-', '-', '-']

# %%
stats
# Out:
#                            id  alignment_score nt_insertions nt_deletions  \
# 0  PC_1030_30_MCHERRY_FORWARD           1072.0
#
#                                        nt_mismatches  \
# 0  4723(A->C); 4724(G->T); 4725(C->G); 4732(T->C)...
#
#                  silent_mutations missense_mutations gap_mutations
# 0  8; 11; 35; 37; 48; 57; 84; 147

# %%
stats
# Out:
#                         id  alignment_score nt_insertions nt_deletions  \
# 0  PC_2090_90_WPRE_REVERSE           1414.0
#
#                                        nt_mismatches  \
# 0  9840(T->C); 9842(C->G); 10071(A->G); 10143(G->...
#
#                                     silent_mutations missense_mutations  \
# 0  47; 48; 124; 148; 149; 167; 168; 206; 207; 239...
#
#   gap_mutations
# 0

# %%
t_start_base
# Out:
# 4999

# %%
import os
os.listdir('peter_data')
# Out:
# ['PC_812288-1043_43_PC-442--Mcherry-Seq-Forward_D07.ab1',
#  'PC_812288-2090_90_WPRE-R_H06.ab1',
#  'PC_812288-3052_28_PC-442--Mcherry-Seq-Forward_D07.ab1',
#  'PC_812288-1036_36_PC-442--Mcherry-Seq-Forward_C12.ab1',
#  'PC_812288-1030_30_PC-442--Mcherry-Seq-Forward_C06.ab1',
#  'PC_812288-1042_42_PC-442--Mcherry-Seq-Forward_D06.ab1',
#  'PC_812288-4054_30_WPRE-R_F07.ab1',
#  'PC_812288-2008_8_WPRE-R_A08.ab1',
#  'PC_812288-2079_79_WPRE-R_G07.ab1',
#  'PC_812288-2088_88_WPRE-R_H04.ab1',
#  'PC_812288-4058_59_WPRE-R_B08.ab1',
#  'PC_812288-4052_28_WPRE-R_D07.ab1',
#  'PC_812288-2055_55_WPRE-R_E07.ab1',
#  'PC_812288-2086_86_WPRE-R_H02.ab1',
#  'PC_812288-2091_91_WPRE-R_H07.ab1',
#  'PC_812288-2016_16_WPRE-R_B04.ab1',
#  'PC_812288-1044_44_PC-442--Mcherry-Seq-Forward_D08.ab1',
#  'PC_812288-1007_7_PC-442--Mcherry-Seq-Forward_A07.ab1',
#  'PC_812288-4022_14_WPRE-R_F03.ab1',
#  'PC_812288-1041_41_PC-442--Mcherry-Seq-Forward_D05.ab1',
#  'PC_812288-2014_14_WPRE-R_B02.ab1',
#  'PC_812288-1055_55_PC-442--Mcherry-Seq-Forward_E07.ab1',
#  'PC_812288-3024_16_PC-442--Mcherry-Seq-Forward_H03.ab1',
#  'PC_812288-3040_24_PC-442--Mcherry-Seq-Forward_H05.ab1',
#  'PC_812288-3009_49_PC-442--Mcherry-Seq-Forward_A02.ab1',
#  'PC_812288-4026_53_WPRE-R_B04.ab1',
#  'PC_812288-1092_92_PC-442--Mcherry-Seq-Forward_H08.ab1',
#  'PC_812288-1039_39_PC-442--Mcherry-Seq-Forward_D03.ab1',
#  'PC_812288-1070_70_PC-442--Mcherry-Seq-Forward_F10.ab1',
#  'PC_812288-1024_24_PC-442--Mcherry-Seq-Forward_B12.ab1',
#  'PC_812288-1040_40_PC-442--Mcherry-Seq-Forward_D04.ab1',
#  'PC_812288-1019_19_PC-442--Mcherry-Seq-Forward_B07.ab1',
#  'PC_812288-3086_46_PC-442--Mcherry-Seq-Forward_F11.ab1',
#  'PC_812288-2020_20_WPRE-R_B08.ab1',
#  'PC_812288-4002_2_WPRE-R_B01.ab1',
#  'PC_812288-2036_36_WPRE-R_C12.ab1',
#  'PC_812288-1045_45_PC-442--Mcherry-Seq-Forward_D09.ab1',
#  'PC_812288-3068_36_PC-442--Mcherry-Seq-Forward_D09.ab1',
#  'PC_812288-3091_66_PC-442--Mcherry-Seq-Forward_C12.ab1',
#  'PC_812288-4040_24_WPRE-R_H05.ab1',
#  'PC_812288-2038_38_WPRE-R_D02.ab1',
#  'PC_812288-1086_86_PC-442--Mcherry-Seq-Forward_H02.ab1',
#  'PC_812288-2074_74_WPRE-R_G02.ab1',
#  'PC_812288-1059_59_PC-442--Mcherry-Seq-Forward_E11.ab1',
#  'PC_812288-4082_42_WPRE-R_B11.ab1',
#  'PC_812288-4037_21_WPRE-R_E05.ab1',
#  'PC_812288-2049_49_WPRE-R_E01.ab1',
#  'PC_812288-2068_68_WPRE-R_F08.ab1',
#  'PC_812288-1067_67_PC-442--Mcherry-Seq-Forward_F07.ab1',
#  'PC_812288-2085_85_WPRE-R_H01.ab1',
#  'PC_812288-1010_10_PC-442--Mcherry-Seq-Forward_A10.ab1',
#  'PC_812288-1084_84_PC-442--Mcherry-Seq-Forward_G12.ab1',
#  'PC_812288-1082_82_PC-442--Mcherry-Seq-Forward_G10.ab1',
#  'PC_812288-2073_73_WPRE-R_G01.ab1',
#  'PC_812288-4081_41_WPRE-R_A11.ab1',
#  'PC_812288-3082_42_PC-442--Mcherry-Seq-Forward_B11.ab1',
#  'PC_812288-3070_38_PC-442--Mcherry-Seq-Forward_F09.ab1',
#  'PC_812288-3085_45_PC-442--Mcherry-Seq-Forward_E11.ab1',
#  'PC_812288-4035_19_WPRE-R_C05.ab1',
#  'PC_812288-2095_95_WPRE-R_H11.ab1',
#  'PC_812288-2066_66_WPRE-R_F06.ab1',
#  'PC_812288-3055_31_PC-442--Mcherry-Seq-Forward_G07.ab1',
#  'PC_812288-3065_33_PC-442--Mcherry-Seq-Forward_A09.ab1',
#  'PC_812288-3006_6_PC-442--Mcherry-Seq-Forward_F01.ab1',
#  'PC_812288-3051_27_PC-442--Mcherry-Seq-Forward_C07.ab1',
#  'PC_812288-3057_58_PC-442--Mcherry-Seq-Forward_A08.ab1',
#  'PC_812288-2026_26_WPRE-R_C02.ab1',
#  'PC_812288-2032_32_WPRE-R_C08.ab1',
#  'PC_812288-3049_25_PC-442--Mcherry-Seq-Forward_A07.ab1',
#  'PC_812288-1091_91_PC-442--Mcherry-Seq-Forward_H07.ab1',
#  'PC_812288-4039_23_WPRE-R_G05.ab1',
#  'PC_812288-3035_19_PC-442--Mcherry-Seq-Forward_C05.ab1',
#  'PC_812288-2053_53_WPRE-R_E05.ab1',
#  'PC_812288-1081_81_PC-442--Mcherry-Seq-Forward_G09.ab1',
#  'PC_812288-4038_22_WPRE-R_F05.ab1',
#  'PC_812288-4073_61_WPRE-R_A10.ab1',
#  'PC_812288-3019_11_PC-442--Mcherry-Seq-Forward_C03.ab1',
#  'PC_812288-3034_18_PC-442--Mcherry-Seq-Forward_B05.ab1',
#  'PC_812288-4024_16_WPRE-R_H03.ab1',
#  'PC_812288-1083_83_PC-442--Mcherry-Seq-Forward_G11.ab1',
#  'PC_812288-4071_39_WPRE-R_G09.ab1',
#  'PC_812288-1037_37_PC-442--Mcherry-Seq-Forward_D01.ab1',
#  'PC_812288-3018_10_PC-442--Mcherry-Seq-Forward_B03.ab1',
#  'PC_812288-1089_89_PC-442--Mcherry-Seq-Forward_H05.ab1',
#  'PC_812288-2072_72_WPRE-R_F12.ab1',
#  'PC_812288-2063_63_WPRE-R_F03.ab1',
#  'PC_812288-3004_4_PC-442--Mcherry-Seq-Forward_D01.ab1',
#  'PC_812288-3053_29_PC-442--Mcherry-Seq-Forward_E07.ab1',
#  'PC_812288-2064_64_WPRE-R_F04.ab1',
#  'PC_812288-1048_48_PC-442--Mcherry-Seq-Forward_D12.ab1',
#  'PC_812288-4065_33_WPRE-R_A09.ab1',
#  'PC_812288-2065_65_WPRE-R_F05.ab1',
#  'PC_812288-2089_89_WPRE-R_H05.ab1',
#  'PC_812288-1012_12_PC-442--Mcherry-Seq-Forward_A12.ab1',
#  'PC_812288-3010_50_PC-442--Mcherry-Seq-Forward_B02.ab1',
#  'PC_812288-2045_45_WPRE-R_D09.ab1',
#  'PC_812288-4053_29_WPRE-R_E07.ab1',
#  'PC_812288-2028_28_WPRE-R_C04.ab1',
#  'PC_812288-4075_63_WPRE-R_C10.ab1',
#  'PC_812288-1090_90_PC-442--Mcherry-Seq-Forward_H06.ab1',
#  'PC_812288-4087_47_WPRE-R_G11.ab1',
#  'PC_812288-4001_1_WPRE-R_A01.ab1',
#  'PC_812288-3007_7_PC-442--Mcherry-Seq-Forward_G01.ab1',
#  'PC_812288-3069_37_PC-442--Mcherry-Seq-Forward_E09.ab1',
#  'PC_812288-2031_31_WPRE-R_C07.ab1',
#  'PC_812288-1032_32_PC-442--Mcherry-Seq-Forward_C08.ab1',
#  'PC_812288-1075_75_PC-442--Mcherry-Seq-Forward_G03.ab1',
#  'PC_812288-2084_84_WPRE-R_G12.ab1',
#  'PC_812288-1087_87_PC-442--Mcherry-Seq-Forward_H03.ab1',
#  'PC_812288-1015_15_PC-442--Mcherry-Seq-Forward_B03.ab1',
#  'PC_812288-2058_58_WPRE-R_E10.ab1',
#  'PC_812288-4070_38_WPRE-R_F09.ab1',
#  'PC_812288-2096_96_WPRE-R_H12.ab1',
#  'PC_812288-3089_64_PC-442--Mcherry-Seq-Forward_A12.ab1',
#  'PC_812288-2047_47_WPRE-R_D11.ab1',
#  'PC_812288-3075_63_PC-442--Mcherry-Seq-Forward_C10.ab1',
#  'PC_812288-1034_34_PC-442--Mcherry-Seq-Forward_C10.ab1',
#  'PC_812288-4059_60_WPRE-R_C08.ab1',
#  'PC_812288-4007_7_WPRE-R_G01.ab1',
#  'PC_812288-2041_41_WPRE-R_D05.ab1',
#  'PC_812288-1021_21_PC-442--Mcherry-Seq-Forward_B09.ab1',
#  'PC_812288-4049_25_WPRE-R_A07.ab1',
#  'PC_812288-3027_54_PC-442--Mcherry-Seq-Forward_C04.ab1',
#  'PC_812288-2081_81_WPRE-R_G09.ab1',
#  'PC_812288-2040_40_WPRE-R_D04.ab1',
#  'PC_812288-2042_42_WPRE-R_D06.ab1',
#  'PC_812288-1071_71_PC-442--Mcherry-Seq-Forward_F11.ab1',
#  'PC_812288-4041_55_WPRE-R_A06.ab1',
#  'PC_812288-2009_9_WPRE-R_A09.ab1',
#  'PC_812288-2029_29_WPRE-R_C05.ab1',
#  'PC_812288-2060_60_WPRE-R_E12.ab1',
#  'PC_812288-4017_9_WPRE-R_A03.ab1',
#  'PC_812288-2002_2_WPRE-R_A02.ab1',
#  'PC_812288-2037_37_WPRE-R_D01.ab1',
#  'PC_812288-2039_39_WPRE-R_D03.ab1',
#  'PC_812288-1049_49_PC-442--Mcherry-Seq-Forward_E01.ab1',
#  'PC_812288-2082_82_WPRE-R_G10.ab1',
#  'PC_812288-4036_20_WPRE-R_D05.ab1',
#  'PC_812288-4023_15_WPRE-R_G03.ab1',
#  'PC_812288-1018_18_PC-442--Mcherry-Seq-Forward_B06.ab1',
#  'PC_812288-1038_38_PC-442--Mcherry-Seq-Forward_D02.ab1',
#  'PC_812288-3039_23_PC-442--Mcherry-Seq-Forward_G05.ab1',
#  'PC_812288-2006_6_WPRE-R_A06.ab1',
#  'PC_812288-4089_64_WPRE-R_A12.ab1',
#  'PC_812288-3037_21_PC-442--Mcherry-Seq-Forward_E05.ab1',
#  'PC_812288-2059_59_WPRE-R_E11.ab1',
#  'PC_812288-2057_57_WPRE-R_E09.ab1',
#  'PC_812288-4042_56_WPRE-R_B06.ab1',
#  'PC_812288-2044_44_WPRE-R_D08.ab1',
#  'PC_812288-1079_79_PC-442--Mcherry-Seq-Forward_G07.ab1',
#  'PC_812288-2077_77_WPRE-R_G05.ab1',
#  'PC_812288-4068_36_WPRE-R_D09.ab1',
#  'PC_812288-2080_80_WPRE-R_G08.ab1',
#  'PC_812288-2033_33_WPRE-R_C09.ab1',
#  'PC_812288-3054_30_PC-442--Mcherry-Seq-Forward_F07.ab1',
#  'PC_812288-1031_31_PC-442--Mcherry-Seq-Forward_C07.ab1',
#  'PC_812288-4019_11_WPRE-R_C03.ab1',
#  'PC_812288-1078_78_PC-442--Mcherry-Seq-Forward_G06.ab1',
#  'PC_812288-4011_51_WPRE-R_C02.ab1',
#  'PC_812288-4088_48_WPRE-R_H11.ab1',
#  'PC_812288-3002_2_PC-442--Mcherry-Seq-Forward_B01.ab1',
#  'PC_812288-2071_71_WPRE-R_F11.ab1',
#  'PC_812288-4074_62_WPRE-R_B10.ab1',
#  'PC_812288-1005_5_PC-442--Mcherry-Seq-Forward_A05.ab1',
#  'PC_812288-2061_61_WPRE-R_F01.ab1',
#  'PC_812288-3011_51_PC-442--Mcherry-Seq-Forward_C02.ab1',
#  'PC_812288-2025_25_WPRE-R_C01.ab1',
#  'PC_812288-3058_59_PC-442--Mcherry-Seq-Forward_B08.ab1',
#  'PC_812288-2048_48_WPRE-R_D12.ab1',
#  'PC_812288-1016_16_PC-442--Mcherry-Seq-Forward_B04.ab1',
#  'PC_812288-2003_3_WPRE-R_A03.ab1',
#  'PC_812288-3072_40_PC-442--Mcherry-Seq-Forward_H09.ab1',
#  'PC_812288-3090_65_PC-442--Mcherry-Seq-Forward_B12.ab1',
#  'PC_812288-1093_93_PC-442--Mcherry-Seq-Forward_H09.ab1',
#  'PC_812288-4090_65_WPRE-R_B12.ab1',
#  'PC_812288-1096_96_PC-442--Mcherry-Seq-Forward_H12.ab1',
#  'PC_812288-1017_17_PC-442--Mcherry-Seq-Forward_B05.ab1',
#  'PC_812288-4009_49_WPRE-R_A02.ab1',
#  'PC_812288-4084_44_WPRE-R_D11.ab1',
#  'PC_812288-4005_5_WPRE-R_E01.ab1',
#  'PC_812288-2023_23_WPRE-R_B11.ab1',
#  'PC_812288-3081_41_PC-442--Mcherry-Seq-Forward_A11.ab1',
#  'PC_812288-3084_44_PC-442--Mcherry-Seq-Forward_D11.ab1',
#  'PC_812288-1006_6_PC-442--Mcherry-Seq-Forward_A06.ab1',
#  'PC_812288-1051_51_PC-442--Mcherry-Seq-Forward_E03.ab1',
#  'PC_812288-2069_69_WPRE-R_F09.ab1',
#  'PC_812288-1073_73_PC-442--Mcherry-Seq-Forward_G01.ab1',
#  'PC_812288-1056_56_PC-442--Mcherry-Seq-Forward_E08.ab1',
#  'PC_812288-2092_92_WPRE-R_H08.ab1',
#  'PC_812288-3005_5_PC-442--Mcherry-Seq-Forward_E01.ab1',
#  'PC_812288-1076_76_PC-442--Mcherry-Seq-Forward_G04.ab1',
#  'PC_812288-1003_3_PC-442--Mcherry-Seq-Forward_A03.ab1',
#  'PC_812288-3071_39_PC-442--Mcherry-Seq-Forward_G09.ab1',
#  'PC_812288-1074_74_PC-442--Mcherry-Seq-Forward_G02.ab1',
#  'PC_812288-4051_27_WPRE-R_C07.ab1',
#  'PC_812288-2018_18_WPRE-R_B06.ab1',
#  'PC_812288-1014_14_PC-442--Mcherry-Seq-Forward_B02.ab1',
#  'PC_812288-3066_34_PC-442--Mcherry-Seq-Forward_B09.ab1',
#  'PC_812288-4091_66_WPRE-R_C12.ab1',
#  'PC_812288-1063_63_PC-442--Mcherry-Seq-Forward_F03.ab1',
#  'PC_812288-1068_68_PC-442--Mcherry-Seq-Forward_F08.ab1',
#  'PC_812288-4067_35_WPRE-R_C09.ab1',
#  'PC_812288-2030_30_WPRE-R_C06.ab1',
#  'PC_812288-3021_13_PC-442--Mcherry-Seq-Forward_E03.ab1',
#  'PC_812288-4033_17_WPRE-R_A05.ab1',
#  'PC_812288-1062_62_PC-442--Mcherry-Seq-Forward_F02.ab1',
#  'PC_812288-1025_25_PC-442--Mcherry-Seq-Forward_C01.ab1',
#  'PC_812288-2010_10_WPRE-R_A10.ab1',
#  'PC_812288-4021_13_WPRE-R_E03.ab1',
#  'PC_812288-3056_32_PC-442--Mcherry-Seq-Forward_H07.ab1',
#  'PC_812288-1094_94_PC-442--Mcherry-Seq-Forward_H10.ab1',
#  'PC_812288-1069_69_PC-442--Mcherry-Seq-Forward_F09.ab1',
#  'PC_812288-1004_4_PC-442--Mcherry-Seq-Forward_A04.ab1',
#  'PC_812288-2021_21_WPRE-R_B09.ab1',
#  'PC_812288-4083_43_WPRE-R_C11.ab1',
#  'PC_812288-2070_70_WPRE-R_F10.ab1',
#  'PC_812288-1009_9_PC-442--Mcherry-Seq-Forward_A09.ab1',
#  'PC_812288-4055_31_WPRE-R_G07.ab1',
#  'PC_812288-3001_1_PC-442--Mcherry-Seq-Forward_A01.ab1',
#  'PC_812288-2052_52_WPRE-R_E04.ab1',
#  'PC_812288-4034_18_WPRE-R_B05.ab1',
#  'PC_812288-1058_58_PC-442--Mcherry-Seq-Forward_E10.ab1',
#  'PC_812288-3017_9_PC-442--Mcherry-Seq-Forward_A03.ab1',
#  'PC_812288-3067_35_PC-442--Mcherry-Seq-Forward_C09.ab1',
#  'PC_812288-2067_67_WPRE-R_F07.ab1',
#  'PC_812288-4020_12_WPRE-R_D03.ab1',
#  'PC_812288-1011_11_PC-442--Mcherry-Seq-Forward_A11.ab1',
#  'PC_812288-4066_34_WPRE-R_B09.ab1',
#  'PC_812288-1065_65_PC-442--Mcherry-Seq-Forward_F05.ab1',
#  'PC_812288-4057_58_WPRE-R_A08.ab1',
#  'PC_812288-2011_11_WPRE-R_A11.ab1',
#  'PC_812288-4069_37_WPRE-R_E09.ab1',
#  'PC_812288-2050_50_WPRE-R_E02.ab1',
#  'PC_812288-3087_47_PC-442--Mcherry-Seq-Forward_G11.ab1',
#  'PC_812288-2022_22_WPRE-R_B10.ab1',
#  'PC_812288-3026_53_PC-442--Mcherry-Seq-Forward_B04.ab1',
#  'PC_812288-3043_57_PC-442--Mcherry-Seq-Forward_C06.ab1',
#  'PC_812288-1026_26_PC-442--Mcherry-Seq-Forward_C02.ab1',
#  'PC_812288-1061_61_PC-442--Mcherry-Seq-Forward_F01.ab1',
#  'PC_812288-3025_52_PC-442--Mcherry-Seq-Forward_A04.ab1',
#  'PC_812288-1033_33_PC-442--Mcherry-Seq-Forward_C09.ab1',
#  'PC_812288-2015_15_WPRE-R_B03.ab1',
#  'PC_812288-4010_50_WPRE-R_B02.ab1',
#  'PC_812288-3020_12_PC-442--Mcherry-Seq-Forward_D03.ab1',
#  'PC_812288-2054_54_WPRE-R_E06.ab1',
#  'PC_812288-1057_57_PC-442--Mcherry-Seq-Forward_E09.ab1',
#  'PC_812288-4025_52_WPRE-R_A04.ab1',
#  'PC_812288-1002_2_PC-442--Mcherry-Seq-Forward_A02.ab1',
#  'PC_812288-2001_1_WPRE-R_A01.ab1',
#  'PC_812288-4056_32_WPRE-R_H07.ab1',
#  'PC_812288-2075_75_WPRE-R_G03.ab1',
#  'PC_812288-2024_24_WPRE-R_B12.ab1',
#  'PC_812288-3033_17_PC-442--Mcherry-Seq-Forward_A05.ab1',
#  'PC_812288-3041_55_PC-442--Mcherry-Seq-Forward_A06.ab1',
#  'PC_812288-1020_20_PC-442--Mcherry-Seq-Forward_B08.ab1',
#  'PC_812288-3036_20_PC-442--Mcherry-Seq-Forward_D05.ab1',
#  'PC_812288-1027_27_PC-442--Mcherry-Seq-Forward_C03.ab1',
#  'PC_812288-4018_10_WPRE-R_B03.ab1',
#  'PC_812288-4086_46_WPRE-R_F11.ab1',
#  'PC_812288-1077_77_PC-442--Mcherry-Seq-Forward_G05.ab1',
#  'PC_812288-1008_8_PC-442--Mcherry-Seq-Forward_A08.ab1',
#  'PC_812288-1072_72_PC-442--Mcherry-Seq-Forward_F12.ab1',
#  'PC_812288-4050_26_WPRE-R_B07.ab1',
#  'PC_812288-4072_40_WPRE-R_H09.ab1',
#  'PC_812288-1052_52_PC-442--Mcherry-Seq-Forward_E04.ab1',
#  'PC_812288-2017_17_WPRE-R_B05.ab1',
#  'PC_812288-1023_23_PC-442--Mcherry-Seq-Forward_B11.ab1',
#  'PC_812288-1047_47_PC-442--Mcherry-Seq-Forward_D11.ab1',
#  'PC_812288-2093_93_WPRE-R_H09.ab1',
#  'PC_812288-3088_48_PC-442--Mcherry-Seq-Forward_H11.ab1',
#  'PC_812288-3083_43_PC-442--Mcherry-Seq-Forward_C11.ab1',
#  'PC_812288-2076_76_WPRE-R_G04.ab1',
#  'PC_812288-2027_27_WPRE-R_C03.ab1',
#  'PC_812288-3073_61_PC-442--Mcherry-Seq-Forward_A10.ab1',
#  'PC_812288-4043_57_WPRE-R_C06.ab1',
#  'PC_812288-1064_64_PC-442--Mcherry-Seq-Forward_F04.ab1',
#  'PC_812288-4085_45_WPRE-R_E11.ab1',
#  'PC_812288-3003_3_PC-442--Mcherry-Seq-Forward_C01.ab1',
#  'PC_812288-1088_88_PC-442--Mcherry-Seq-Forward_H04.ab1',
#  'PC_812288-3074_62_PC-442--Mcherry-Seq-Forward_B10.ab1',
#  'PC_812288-3023_15_PC-442--Mcherry-Seq-Forward_G03.ab1',
#  'PC_812288-2035_35_WPRE-R_C11.ab1',
#  'PC_812288-1029_29_PC-442--Mcherry-Seq-Forward_C05.ab1',
#  'PC_812288-1085_85_PC-442--Mcherry-Seq-Forward_H01.ab1',
#  'PC_812288-3038_22_PC-442--Mcherry-Seq-Forward_F05.ab1',
#  'PC_812288-1028_28_PC-442--Mcherry-Seq-Forward_C04.ab1',
#  'PC_812288-1066_66_PC-442--Mcherry-Seq-Forward_F06.ab1',
#  'PC_812288-2062_62_WPRE-R_F02.ab1',
#  'PC_812288-2051_51_WPRE-R_E03.ab1',
#  'PC_812288-1035_35_PC-442--Mcherry-Seq-Forward_C11.ab1',
#  'PC_812288-2005_5_WPRE-R_A05.ab1',
#  'PC_812288-2007_7_WPRE-R_A07.ab1',
#  'PC_812288-2056_56_WPRE-R_E08.ab1',
#  'PC_812288-4027_54_WPRE-R_C04.ab1',
#  'PC_812288-1060_60_PC-442--Mcherry-Seq-Forward_E12.ab1',
#  'PC_812288-2094_94_WPRE-R_H10.ab1',
#  'PC_812288-3050_26_PC-442--Mcherry-Seq-Forward_B07.ab1',
#  'PC_812288-1053_53_PC-442--Mcherry-Seq-Forward_E05.ab1',
#  'PC_812288-1013_13_PC-442--Mcherry-Seq-Forward_B01.ab1',
#  'PC_812288-1046_46_PC-442--Mcherry-Seq-Forward_D10.ab1',
#  'PC_812288-1054_54_PC-442--Mcherry-Seq-Forward_E06.ab1',
#  'PC_812288-4003_3_WPRE-R_C01.ab1',
#  'PC_812288-4008_8_WPRE-R_H01.ab1',
#  'PC_812288-4004_4_WPRE-R_D01.ab1',
#  'PC_812288-1050_50_PC-442--Mcherry-Seq-Forward_E02.ab1',
#  'PC_812288-1080_80_PC-442--Mcherry-Seq-Forward_G08.ab1',
#  'PC_812288-2012_12_WPRE-R_A12.ab1',
#  'PC_812288-2013_13_WPRE-R_B01.ab1',
#  'PC_812288-3022_14_PC-442--Mcherry-Seq-Forward_F03.ab1',
#  'PC_812288-2034_34_WPRE-R_C10.ab1',
#  'PC_812288-3008_8_PC-442--Mcherry-Seq-Forward_H01.ab1',
#  'PC_812288-2046_46_WPRE-R_D10.ab1',
#  'PC_812288-3042_56_PC-442--Mcherry-Seq-Forward_B06.ab1',
#  'PC_812288-2043_43_WPRE-R_D07.ab1',
#  'PC_812288-3059_60_PC-442--Mcherry-Seq-Forward_C08.ab1',
#  'PC_812288-4006_6_WPRE-R_F01.ab1',
#  'PC_812288-2078_78_WPRE-R_G06.ab1',
#  'PC_812288-2004_4_WPRE-R_A04.ab1',
#  'PC_812288-2019_19_WPRE-R_B07.ab1',
#  'PC_812288-2087_87_WPRE-R_H03.ab1',
#  'PC_812288-1095_95_PC-442--Mcherry-Seq-Forward_H11.ab1',
#  'PC_812288-1001_1_PC-442--Mcherry-Seq-Forward_A01.ab1',
#  'PC_812288-2083_83_WPRE-R_G11.ab1',
#  'PC_812288-1022_22_PC-442--Mcherry-Seq-Forward_B10.ab1']

# %%
from pysanger import *
import matplotlib.pyplot as plt

import os
from Bio import SeqIO

from tqdm.notebook import tqdm

def tokenize_fp_make_id(inp):
    tokens = inp.replace('-', '_').split('_')
    user = tokens[0]
    construct = tokens[2]
    num = tokens[3]

    forward = 'Mcherry' in tokens
    reverse = 'WPRE' in tokens

    if not forward and not reverse:
        raise Exception('Neither forward nor reverse! Invalid filename.')
    else:
        if forward:
            primer = 'MCHERRY'
            direction = 'FORWARD'
            strand = 1
        else:
            primer = 'WPRE'
            direction = 'REVERSE'
            strand = -1

    id = f"{user}_{construct}_{num}_{primer}_{direction}"

    return id, strand

#read in template plasmid
with open("data/bfp-expression-control-mcherry-flag-hlpla-pcdna3-w37v.fasta") as file:
    for record in SeqIO.parse(file, "fasta"):
        template = record.seq

os.makedirs('output', exist_ok=True)

for fp in tqdm(os.listdir('peter_data')):
    #abidata = abi_to_dict("data/PC_806488-574_2_PC-442--Mcherry-Seq-Forward_B10.ab1")
    id, strand = tokenize_fp_make_id(fp)
    abidata = abi_to_dict(f"peter_data/{fp}")

    if strand == 1:
        template_limits = (4660, 5250)
    else:
        template_limits = (5000, 5740)
    fig = visualize(id, abidata, template=template, strand=strand, fig=None, region="read", translation_limits = (4702, None), template_limits = template_limits)
    fig.savefig(f'output/{id}.png', bbox_inches = "tight")
    plt.close()
# Out:
#   0%|          | 0/324 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 51
#      49     template_limits = (5000, 5740)
#      50 fig = visualize(id, abidata, template=template, strand=strand, fig=None, region="read", translation_limits = (4702, None), template_limits = template_limits)
# ---> 51 fig.savefig(f'output/{id}.png', bbox_inches = "tight")
#      52 plt.close()
#
# AttributeError: 'tuple' object has no attribute 'savefig'
# Error in callback <function flush_figures at 0x7f1df35d9c60> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/matplotlib/backend_bases.py:2346, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
# -> 2346         bbox_inches = self.figure.get_tightbbox(
#    2347             renderer, bbox_extra_artists=bbox_extra_artists)
#    2348         if pad_inches is None:
#    2349             pad_inches = rcParams['savefig.pad_inches']
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/matplotlib/figure.py:1744, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1741     artists = bbox_extra_artists
#    1743 for a in artists:
# -> 1744     bbox = a.get_tightbbox(renderer)
#    1745     if bbox is not None:
#    1746         bb.append(bbox)
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/matplotlib/artist.py:367, in Artist.get_tightbbox(self, renderer)
#     352 def get_tightbbox(self, renderer=None):
#     353     """
#     354     Like `.Artist.get_window_extent`, but includes any clipping.
#     355
#    (...)
#     365         The enclosing bounding box (in figure pixel coordinates).
#     366     """
# --> 367     bbox = self.get_window_extent(renderer)
#     368     if self.get_clip_on():
#     369         clip_box = self.get_clip_box()
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/matplotlib/text.py:958, in Text.get_window_extent(self, renderer, dpi)
#     953 if self._renderer is None:
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
# --> 958 with cbook._setattr_cm(self.figure, dpi=dpi):
#     959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#
# File ~/miniconda3/envs/biopython/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:2028, in _setattr_cm(obj, **kwargs)
#    2026 try:
#    2027     for attr, val in kwargs.items():
# -> 2028         setattr(obj, attr, val)
#    2029     yield
#    2030 finally:
#
# File ~/miniconda3/envs/biopython/lib/python3.11/site-packages/matplotlib/figure.py:2736, in Figure._set_dpi(self, dpi, forward)
#    2733 def _get_dpi(self):
#    2734     return self._dpi
# -> 2736 def _set_dpi(self, dpi, forward=True):
#    2737     """
#    2738     Parameters
#    2739     ----------
#    (...)
#    2743         Passed on to `~.Figure.set_size_inches`
#    2744     """
#    2745     if dpi == self._dpi:
#    2746         # We don't want to cause undue events in backends.
#
# KeyboardInterrupt:
